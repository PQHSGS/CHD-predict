# %% [markdown]
# <a href="https://colab.research.google.com/github/PQHSGS/CHD-predict/blob/main/Innov8_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BÁO CÁO ĐỀ TÀI KHÓA HỌC AI ADVENTURE**

# %% [markdown]
# **Ý tưởng và mục tiêu**
# - CHD (Coronary Heart Disease), hay bệnh mạch vành, là một tình trạng xảy ra khi các mạch máu cung cấp máu cho tim (động mạch vành) bị hẹp hoặc tắc nghẽn.
# - Nguyên nhân gây nên chủ yếu là do sự tích tụ của mảng bám trong động mạch vành, bao gồm chất béo, cholesterol, canxi,.... Các yếu tố nguy cơ góp phần bao gồm hút thuốc, cao huyết áp, tiểu đường, cholesterol cao, béo phì, lối sống ít vận động, và tiền sử gia đình có bệnh tim mạch.
# - Vì vậy Nhóm hướng tới mục tiêu xây dựng mô hình phân tích và chẩn đoán nguy cơmắc bệnh CHD trong tương lai dựa trên chỉ số sức khỏe của mỗi cá nhân.
# - Dữ liệu huấn luyện là một thống kê tim mạch bao gồm các thông số sinh học và thói quen sinh hoạt của hơn 4000 cá thể cư dân của thị trấn Framingham, Massachusetts.

# %% [markdown]
# **Tóm tắt nội dung**
#
#
# 1.   Khai báo thư viện và tải dữ liệu
# 2.   Tổng quan về dữ liệu
# 3.   Trực quan hóa dữ liệu
# 4.   Tiền xử lý dữ liệu
# 5.   Áp dụng các mô hình học máy
# 6.   Cách mô hình đưa ra lựa chọn
# 7.   Tổng kết

# %% [markdown]
# #Khai báo thư viện và tải dữ liệu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/framingham.csv")

# %% [markdown]
# #Tổng quan về dữ liệu

# %% [markdown]
# Bộ dữ liệu có sẵn công khai trên trang web [Kaggle](https://www.kaggle.com/datasets/aasheesh200/framingham-heart-study-dataset) và xuất phát từ một thống kê về tim mạch diễn ra định kì với cư dân của thị trấn Framingham, Massachusetts. Dữ liệu bao hàm các thông số sinh học, tiền sử bệnh lý, thói quen sinh hoạt mà được cho là liên quan mật thiết đến bệnh tim mạch vành CHD

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# * **male:** 1 [Nam] , 0 [Nữ]
# * **age:** Tuổi của bệnh nhân
# * **education:** Trình độ giáo dục (4 [PhD] , 3 [Master], 2 [Bachelor], 1 [High school])
# * **curentSmoker:** Hiện có đang hút thuốc hay không (1 [Có] , 0 [Không])
# * **cigsPerDay:** Lượng thuốc lá hút 1 ngày
# * **BPMeds:** Tiền sử bị bệnh huyết áp (1 [Có], 0 [Không])
# * **prevalentStroke:** Tiền sử bị đột quỵ (1 [Có] , 0 [Không])
# * **prevalentHyp:** Tiền sử tăng huyết áp (1 [Có] , 0 [Không])
# * **diabetes:** Bệnh tiểu đường (1 [Có] , 0 [Không])
# * **totChol:** Chỉ số cholesterol
# * **sysBP:** Huyết áp tâm thu
# * **diaBP:** Huyết áp tâm trương
# * **BMI:** Chỉ số BMI
# * **heartRate:** Nhịp tim
# * **glucose :** Lượng đường trong máu
# * **TenYearCHD :** 1 [Có] , 0 [Không]

# %%
print(f"Kích thước của dữ liệu: {df.shape}")
print(f"Info của dataset :\n")
print(df.info())
# Out:
# Kích thước của dữ liệu: (4240, 16)
# Info của dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
# ...

# %%
print(f"Các thông số đặc trưng :")
round(df.describe().T,ndigits=2)
# Out:
# Các thông số đặc trưng :
#                   count    mean    std     min     25%    50%     75%    max
# male             4240.0    0.43   0.50    0.00    0.00    0.0    1.00    1.0
# age              4240.0   49.58   8.57   32.00   42.00   49.0   56.00   70.0
# education        4135.0    1.98   1.02    1.00    1.00    2.0    3.00    4.0
# currentSmoker    4240.0    0.49   0.50    0.00    0.00    0.0    1.00    1.0
# cigsPerDay       4211.0    9.01  11.92    0.00    0.00    0.0   20.00   70.0
# BPMeds           4187.0    0.03   0.17    0.00    0.00    0.0    0.00    1.0
# prevalentStroke  4240.0    0.01   0.08    0.00    0.00    0.0    0.00    1.0
# prevalentHyp     4240.0    0.31   0.46    0.00    0.00    0.0    1.00    1.0
# diabetes         4240.0    0.03   0.16    0.00    0.00    0.0    0.00    1.0
# totChol          4190.0  236.70  44.59  107.00  206.00  234.0  263.00  696.0
# sysBP            4240.0  132.35  22.03   83.50  117.00  128.0  144.00  295.0
# ...

# %%
df.isna().sum().to_frame().T
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     0    0        105              0          29      53                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP  BMI  heartRate  glucose  \
# 0             0         0       50      0      0   19          1      388
#
#    TenYearCHD
# 0           0

# %%
sns.barplot(df.isna().sum(),orient="h")
plt.title("Phân phối dữ liệu NaN")
plt.show()

# %% [markdown]
# Có hơn 600 ô dữ liệu bị để trống trong đó 'glucose' là đặc trưng có nhiều điểm bị thiếu nhất.

# %%
dup = df[df.duplicated()].shape[0]
print(f"Có tổng cộng {dup} lặp dữ liệu lặp")

df.drop_duplicates(keep='first',inplace=True)
print(f"Kích thước dữ liệu sau khi loại bỏ duplicate: {df.shape[0]}")
# Out:
# Có tổng cộng 0 lặp dữ liệu lặp
# Kích thước dữ liệu sau khi loại bỏ duplicate: 4240

# %% [markdown]
# #Trực quan hóa dữ liệu

# %% [markdown]
# **Biểu đồ phân phối tổng quan**

# %%
num_cols = 4
num_rows = 4
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(16, 12))
for i, col in enumerate(df.columns):
    row_num = i // num_cols
    col_num = i % num_cols
    kde=df[col].nunique()>4
    sns.histplot(df,x=df[col],hue="TenYearCHD",kde=kde,ax=axes[row_num, col_num],multiple='dodge')
plt.title("Biểu đồ phân phối giá trị các đặc trưng")
plt.tight_layout()
plt.show()

# %% [markdown]
# Dựa vào biểu đồ phân phối trên ta có thể nhận thấy vài điều:
# - Giới tính không ảnh hưởng nhiều đến nguy cơ mắc bệnh
# - Đa số người có nguy cơ cao đều là người độ tuổi trung niên trở lên
# - Các dữ liệu rời rạc bị mất cân bằng đặc biệt là các đặc trưng về tiền sử bệnh lý
# - Các dữ liệu khác đều có outliers

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
sns.histplot(df,x='male',hue='TenYearCHD',ax=ax1,multiple='dodge')
sns.histplot(df,x='education',hue='TenYearCHD',ax=ax2,multiple='dodge')
# Out:
# <Axes: xlabel='education', ylabel='Count'>

# %%
chol=df[['totChol','BMI','glucose','TenYearCHD']]
sns.pairplot(chol,hue='TenYearCHD')
plt.show()

# %% [markdown]
# Mặc dù dữ liệu của 4 đặc trưng này dao động mạnh nhưng không cho thấy một liên hệ tuyến tính rõ ràng với nhau cũng như là với nguy cơ mắc bệnh.

# %% [markdown]
# <a id="7"></a>
# # Tiền xử lý dữ liệu

# %% [markdown]
# **Feature Selection**

# %% [markdown]
# Biểu đồ tương quan

# %%
plt.subplots(figsize =(12, 8))
num=df[['age','education','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose','TenYearCHD']]
num.dropna(inplace=True)
p=sns.heatmap(num.corr(), square=True, cbar_kws=dict(shrink =.99),
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Chỉ số tương quan giữa các đặc trưng\n", fontsize=25)
plt.show()

# %% [markdown]
# Dựa vào biểu đồ trên, ta nhận thấy được rằng đặc trưng 'TenYearCHD' bị ảnh hưởng tuyến tính chủ yếu bởi 4 yếu tố:
# - age: độ tuổi
# - sysBP, diaBP: Huyết áp tâm thu, huyết áp tâm trương
# - glucose: lượng đường trong máu

# %% [markdown]
# Vậy còn các đặc trưng rời rạc thì sao, vì giá trị ít hơn rất nhiều nên tương quan tuyến tính của chúng sẽ rất thấp. Ta cần một cách tiếp cận khác phù hợp hơn là thuật toán trích chọn Khi-bình phương.

# %%
from sklearn.feature_selection import chi2
df_cat=df[['male','currentSmoker','BPMeds','prevalentStroke','prevalentHyp','diabetes','TenYearCHD']]
df_cat.dropna(inplace=True)
X=df_cat.drop('TenYearCHD',axis=1)
chi_scores = chi2(X, df_cat['TenYearCHD'])

# %%
chi_values = pd.Series(chi_scores[0], index=X.columns)
chi_values.sort_values(ascending=False, inplace=True)
chi_values.plot.bar()
plt.title("Chi-square Score")
plt.show()

# %% [markdown]
# Ta thấy 'prevalentHyp' là đặc trưng có ảnh hưởng vượt trội so với các đặc trưng còn lại trong nhóm.

# %%
sns.histplot(df, x='cigsPerDay', hue='currentSmoker',multiple='dodge')
plt.show()

# %% [markdown]
# Dựa vào những suy luận trên  ta trích chọn ra 5 đặc trưng được cho là có thể sẽ ảnh hưởng đến nguy cơ mắc bệnh ở tương lai.

# %%
data=df[['age','prevalentHyp','sysBP','diaBP','glucose','TenYearCHD']]
outlier=((data['glucose']>200)|(data['sysBP']>200)|(data['diaBP']>150)) #loại bỏ một số outliers
data=data[~outlier]
data.shape
# Out:
# (4171, 6)

# %% [markdown]
# **Xử lý NaN**
#
# - Như đề cập ở trên, dataset hiện đang thiếu khoảng 600 giá trị, chủ yếu nằm ở cột "glucose" (~10% lượng thông tin của đặc trưng).
# Khi điền dữ liệu vào các ô đó ta cần đảm bảo sự phân phối dữ liệu và các mối tương quan giữa các cột không bị xê dịch nhiều.
#
#   => Các phép điền giá trị trung bình, trung vị, mốt sẽ dễ làm thay đổi điều đó.
#
# - Ta sẽ tiếp cận bằng một phương thức khác là hàm KNNImputer() được dựa trên thuật toán KNN, điền dữ liệu bị thiếu của 1 điểm dựa vào đặc trưng tương ứng của các điểm lân cận nó.

# %%
#chia tách dữ liệu trước khi impute để tránh rỏ rỉ dữ liệu
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.drop("TenYearCHD",axis=1),data["TenYearCHD"],test_size=0.2,random_state=42,stratify=data["TenYearCHD"])
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3336, 5), (3336,), (835, 5), (835,))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline


preprocessing = Pipeline([
    ('imputer', KNNImputer()),
    ('scaler', StandardScaler())
])

x_train_processed = preprocessing.fit_transform(x_train)
x_test_processed = preprocessing.transform(x_test)

x_train_processed=pd.DataFrame(x_train_processed,columns=x_train.columns)
x_test_processed=pd.DataFrame(x_test_processed,columns=x_test.columns)
print(x_train_processed.shape)
print(x_test_processed.shape)
x_train_processed.head()
# Out:
# (3336, 5)
# (835, 5)
#         age  prevalentHyp     sysBP     diaBP   glucose
# 0  0.536359     -0.662700 -0.072600  0.212072  0.322379
# 1  0.184643      1.508978  1.514187  1.867795 -1.051111
# 2  0.770835     -0.662700 -0.438781  0.212072  1.352497
# 3  0.301882     -0.662700 -1.634974 -1.530794 -0.295692
# 4  1.474266      1.508978  0.586527  0.647789  0.185030

# %% [markdown]
# **Resampling**

# %% [markdown]
# - Những người có nguy cơ mắc CHD ít hơn nhiều với người không bị (~1:6) nên ta phải ứng phó với vấn đề mất cân bằng dữ liệu.
# - Ta sử dụng thuật toán SMOTE để oversampling nhãn minority, với hàm cụ thể ở đây là biến thể SMOTENC, hỗ trợ cả đặc trưng rời rạc và liên tục.

# %%
from imblearn.over_sampling import SMOTENC
smt=SMOTENC(categorical_features=['prevalentHyp'],sampling_strategy=0.8, random_state=42)
x_train_processed,y_train=smt.fit_resample(x_train_processed,y_train)

# %%
x_train_processed.shape, y_train.shape, x_test_processed.shape, y_test.shape
# Out:
# ((5131, 5), (5131,), (835, 5), (835,))

# %%
y_train.value_counts()
# Out:
# TenYearCHD
# 0    2851
# 1    2280
# Name: count, dtype: int64

# %% [markdown]
# #Áp dụng các mô hình học máy

# %% [markdown]
# Ta áp dụng các thuật toán phân loại như Logistic Regression, Naive Bayes, Support Vector Machine, Decision Tree và Gradient Boosting.
# Mặt khác, để phù hợp với mục tiêu của mô hình (cảnh báo bệnh), ta sẽ hạ ngưỡng xác suất (mặc định 0.5) xuống còn 0.4.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,recall_score,precision_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

model=[LogisticRegression(C= 0.01),
       BernoulliNB(alpha=0.1),
       SVC(C=0.1,gamma=0.01,degree=3,class_weight='balanced',probability=True),
       DecisionTreeClassifier(criterion='entropy', splitter= 'random',class_weight='balanced',max_depth=20),
       RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=10,class_weight='balanced'),
       XGBClassifier(n_estimators=1000, learning_rate=0.05, n_jobs=-1),]
model_name=["Logistic Regression","Bernoulli Naive Bayes","Support Vector Machine","Decision Tree","Random Forest","XGBoost"]
model_performance=[]
for i in range(len(model)):
  model[i].fit(x_train_processed,y_train)
  y_pred=(model[i].predict_proba(x_test_processed)[:,1]>=0.4).astype(int)
  acc=round(accuracy_score(y_test,y_pred)*100,ndigits=2)
  recall=round(recall_score(y_test,y_pred)*100,ndigits=2)
  precision=round(precision_score(y_test,y_pred)*100,ndigits=2)
  scores=[acc,recall,precision]
  model_performance.append(scores)
model_performance=pd.DataFrame(model_performance,columns=["Accuracy","Recall","Precision"],index=model_name)
model_performance
# Out:
#                         Accuracy  Recall  Precision
# Logistic Regression        59.76   76.86      23.19
# Bernoulli Naive Bayes      64.43   64.46      23.49
# Support Vector Machine     60.12   76.03      23.23
# Decision Tree              69.34   23.97      15.03
# Random Forest              58.20   63.64      20.16
# XGBoost                    77.72   22.31      22.69

# %% [markdown]
# **Kết luận:** Độ chính xác của Accuracy và Recall tỉ lệ nghịch với nhau, không thể đạt được cả 2 cùng 1 lúc. Đa số các mô hình có chỉ số Recall cao; tuy nhiên, precision đều dao động ở mức 20% (nhiều cảnh báo giả).

# %% [markdown]
# #Cách mô hình đưa ra lựa chọn

# %% [markdown]
# - Ta sẽ khai phá 'nội bộ' mô hình dự đoán để xem cách chúng đưa ra lựa chọn đối với mỗi trường hợp. Ở đây ta sẽ dùng thư viện SHAP và thuật toán đại diện Logistic Regression.
# - Cụ thể, SHAP sẽ đưa ra trọng số thuật toán của từng đặc trưng trong điểm dữ liệu được chọn đó. Ta sẽ dựa vào độ lớn và chiều của trọng số để phán đoán rằng đặc trưng nào có ảnh hưởng lớn nhất trong từng trường hợp cụ thể.

# %%
pip install shap

# %%
lr=LogisticRegression(C= 0.01)
lr.fit(x_train_processed,y_train)
y_pred=(lr.predict_proba(x_test_processed)[:,1]>=0.4).astype(int)
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()
plt.show()
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.57      0.71       714
#            1       0.23      0.77      0.36       121
#
#     accuracy                           0.60       835
#    macro avg       0.58      0.67      0.53       835
# weighted avg       0.83      0.60      0.66       835

# %% [markdown]
# Ta chú ý đến nhóm False Positive vì bị dự đoán sai nhiều nhất.

# %%
fp_id=[i for i in range (y_pred.shape[0]) if y_pred[i] == 1 and y_test.iloc[i]==0]
fp=x_test_processed.iloc[fp_id]

# %%
fp.shape[0]
# Out:
# 387

# %%
import shap
from random import randint
explain=shap.Explainer(model[0],x_train_processed)
shap_values=explain(x_test_processed)
#nhóm false positive
id=fp.index[randint(0,fp.shape[0]-1)]
shap.plots.waterfall(shap_values[id])

# %% [markdown]
# Ở hình trên, các ô màu đỏ thể hiện cho việc bạn có nguy cơ mắc bệnh còn ô màu xanh thể hiện cho việc không mắc bệnh.

# %% [markdown]
# Đa số các trường hợp False Positive đều bị ảnh hưởng lớn bởi số tuổi, tiền sử tăng huyết áp và huyết áp tâm thu. Và kể cả khi các đặc trưng khác cùng tuân theo 1 chiều hướng thì chỉ riêng những đặc trưng trên cũng đủ để chi phối và đổi chiều dự đoán.

# %% [markdown]
# Ở đây ta thấy tuổi tác không liên quan trực tiếp đến nguy cơ mắc bệnh mà thực tê nó sẽ dẫn tới sự gia tăng các thông số như cholesterol, đường trong máu cũng như các nguy cơ đột quỵ, tiểu đường

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3)
fig.set_size_inches(15,5)
sns.histplot(df,x='age', hue = 'BPMeds',ax=ax1)
sns.histplot(df,x='age',hue='prevalentStroke',ax=ax2)
sns.histplot(df,x='age',hue='diabetes',ax=ax3)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
Các bệnh tiểu đường, huyết áp, đột quỵ đều nằm ở độ tuổi 40-60

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,5))
sns.histplot(df,x='diabetes',hue='TenYearCHD',ax=ax1,multiple='dodge')
sns.histplot(df,x='BPMeds',hue='TenYearCHD',ax=ax2,multiple='dodge')
sns.histplot(df,x='prevalentStroke',hue='TenYearCHD',ax=ax3,multiple='dodge')
# Out:
# <Axes: xlabel='prevalentStroke', ylabel='Count'>

# %% [markdown]
# Mặc dù những người bệnh tiểu đường, có tiền sử bệnh huyết áp hoặc từng đột quỵ đa số được chẩn đoán là cũng sẽ mắc bệnh tim mạch vành, nhưng thuật toán chi2 không cho rằng chúng quan trọng như 'prevalentHyp'.

# %% [markdown]
# Điều này có thể lí giải là vì các đặc trưng còn lại có tình trạng chênh lệch dữ liệu cực mạnh (giá trị 1 cực ít so với giá trị 0) nên không đủ để hình thành ảnh hưởng (bị thuật toán coi là outlier, bị chi phối bởi quá nhiều giá trị 0) hoặc thừa thãi không cần thiết (VD: cigsPerDay > 0 <=> currentSmoker =1).

# %% [markdown]
# #Tổng kết
# **Đánh giá mô hình**
#
# - Các mô hình đều tuân theo quy luật tỉ lệ nghịch giữa chỉ số Accuracy và Recall
#
# - Đặc biệt Precision của tất cả mô hình đều rất thấp
#
# - Mô hình có tiềm năng phù hợp cao nhất là thuật toán Logistic Regression, Naive Bayes, Random Forest và Support Vector Machine
#
# **Ưu nhược điểm**
# - Ưu điểm: Mô hình có chỉ số Recall cao, tài nguyên tiêu hao ít, dữ liệu được cập nhật liên tục và không phải tiền xử lý nhiều
# - Nhược điểm: Mô hình có chỉ số Precision thấp (nhiều cảnh báo giả) và chưa giải quyết được vấn đề mất cân bằng dữ liệu
#
# **Mở rộng**
# - Huấn luyện được thuật toán có thể học được những đặc trưng bị sót bây giờ.
# - Dữ liệu có thể mở rộng hơn nữa để có thể trích xuất thông tin từ những đặc trưng như chỉ số cholesteron, nhịp tim, tiền sử đột quỵ mà hiện giờ đang bị mất cân bằng dữ liệu mạnh
